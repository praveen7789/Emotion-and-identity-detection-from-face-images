# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\srikanth\anaconda\lib\site-packages (3.4.0.12)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\srikanth\anaconda\lib\site-packages (from opencv-python) (1.14.0)
# notebook 5.4.0 requires ipykernel, which is not installed.
# jupyter 1.0.0 requires ipykernel, which is not installed.
# jupyter-console 5.2.0 requires ipykernel, which is not installed.
# ipywidgets 7.1.1 requires ipykernel>=4.5.1, which is not installed.

# %%
import cv2
import numpy as np

# %% [markdown]
# # Color Space
# ![hsvc](hsvcol.jpg)

# %% [markdown]
# # Machine Leanring POV
# - Reading image
# - Converting into grayscale
# - Thresholding (Binary image)
# - Resize and reshape

# %% [markdown]
# **Step -1 : Reading Image**

# %%
img = cv2.imread('image_2.jpg') # reading image

# %%
img.shape
# Out:
# (343, 473, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img)
plt.show()

# %%
r, g, b  = cv2.split(img)

# %%
plt.figure(figsize=(15,8))
plt.subplot(131)
plt.imshow(r, cmap ='gray')
plt.title('Red Region')

plt.subplot(132)
plt.imshow(g, cmap ='gray')
plt.title('Green Region')

plt.subplot(133)
plt.imshow(b, cmap ='gray')
plt.title('Blue Region')
plt.show()

plt.imshow(img)
plt.title('Blue Green Red Region')
plt.show()

# %%
img_new = cv2.merge((b,g,r)) # merging

# %%
plt.figure(figsize=(15,8))
plt.subplot(131)
plt.imshow(r, cmap ='gray')
plt.title('Blue Region')

plt.subplot(132)
plt.imshow(g, cmap ='gray')
plt.title('Gree Region')

plt.subplot(133)
plt.imshow(b, cmap ='gray')
plt.title('Red Region')
plt.show()

plt.imshow(img_new)
plt.title('Blue Green Red Region')
plt.show()

# %% [markdown]
# **Step - 2: Converting into Grayscale**

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (343, 473)

# %%
plt.imshow(gray,cmap = 'gray')
plt.show()

# %%
cv2.imwrite('grayimag.png',gray)
# Out:
# True

# %%
gray.min(), gray.max()
# Out:
# (1, 240)

# %% [markdown]
# **Step - 3 : Thresholding**

# %%
ret, thresh1 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)

# %%
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.imshow(thresh1,cmap='gray')
plt.title('BINARY')
plt.subplot(122)
plt.imshow(thresh2,cmap='gray')
plt.title('BINARY INV')
plt.show()
